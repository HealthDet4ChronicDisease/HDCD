# %%
import pandas as pd
import numpy as np
import scipy.stats as sp
import altair as alt
import geopandas as gpd

from vega_datasets import data

# %%
# counties = data/us-10m.json

counties = alt.topo_feature(data.us_10m.url, feature='counties')
background = alt.Chart(counties).mark_geoshape(
    fill='lightgray',
    stroke='white'
).project('albersUsa')

background
# Out:
# alt.Chart(...)

# %%
counties = gpd.read_file('https://gist.githubusercontent.com/sdwfrost/d1c73f91dd9d175998ed166eb216994a/raw/e89c35f308cee7e2e5a784e1d3afc5d449e9e4bb/counties.geojson')
counties_zip = pd.read_csv('https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv')

# %%
counties['state_fips'] = counties['STATEFP'].astype('int')
counties
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID           NAME LSAD  \
# 0         06      075  00277302  0500000US06075  06075  San Francisco   06
# 1         25      025  00606939  0500000US25025  25025        Suffolk   06
# 2         31      007  00835826  0500000US31007  31007         Banner   06
# 3         37      181  01008591  0500000US37181  37181          Vance   06
# 4         48      421  01383996  0500000US48421  48421        Sherman   06
# ...      ...      ...       ...             ...    ...            ...  ...
# 3215      29      163  00758536  0500000US29163  29163           Pike   06
# 3216      72      001  01804480  0500000US72001  72001       Adjuntas   13
# 3217      19      079  00465228  0500000US19079  19079       Hamilton   06
# 3218      19      027  00465203  0500000US19027  19027        Carroll   06
# 3219      13      073  00348865  0500000US13073  13073       Columbia   06
#
#            ALAND     AWATER  \
# 0      121485107  479107241
# ...

# %%
counties_zip['NAME'] = counties_zip['county']
counties_zip
# Out:
#        state_fips    state state_abbr zipcode      county        city  \
# 0               1  Alabama         AL   35004   St. Clair       Acmar
# 1               1  Alabama         AL   35005   Jefferson  Adamsville
# 2               1  Alabama         AL   35006   Jefferson       Adger
# 3               1  Alabama         AL   35007      Shelby    Keystone
# 4               1  Alabama         AL   35010  Tallapoosa    New site
# ...           ...      ...        ...     ...         ...         ...
# 33098          56  Wyoming         WY   83126     Lincoln       Smoot
# 33099          56  Wyoming         WY   83127     Lincoln      Thayne
# 33100          56  Wyoming         WY   83128     Lincoln      Alpine
# 33101          56  Wyoming         WY   831HH     Lincoln  Zcta 831hh
# 33102          56  Wyoming         WY   831XX     Lincoln  Zcta 831xx
#
#              NAME
# 0       St. Clair
# 1       Jefferson
# 2       Jefferson
# 3          Shelby
# 4      Tallapoosa
# ...

# %%
counties.merge(counties_zip[['state_fips', 'zipcode', 'NAME']], on=['state_fips', 'NAME'], how='left')
# Out:
#       STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID           NAME LSAD  \
# 0          06      075  00277302  0500000US06075  06075  San Francisco   06
# 1          06      075  00277302  0500000US06075  06075  San Francisco   06
# 2          06      075  00277302  0500000US06075  06075  San Francisco   06
# 3          06      075  00277302  0500000US06075  06075  San Francisco   06
# 4          06      075  00277302  0500000US06075  06075  San Francisco   06
# ...       ...      ...       ...             ...    ...            ...  ...
# 32343      13      073  00348865  0500000US13073  13073       Columbia   06
# 32344      13      073  00348865  0500000US13073  13073       Columbia   06
# 32345      13      073  00348865  0500000US13073  13073       Columbia   06
# 32346      13      073  00348865  0500000US13073  13073       Columbia   06
# 32347      13      073  00348865  0500000US13073  13073       Columbia   06
#
#            ALAND     AWATER  \
# ...
