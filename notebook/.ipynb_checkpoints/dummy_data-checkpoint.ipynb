# %% [markdown]
# # Dummy Data Wrangling

# %%
import sys
import os

# navigate to main HDCD directory
os.getcwd()
os.chdir('..')

import pandas as pd
import numpy as np

# %%
dummy_folder = os.getcwd() + '/dummy_data'

condition_file = 'condition_data.csv'
observation_file = 'observation_data.csv'
person_file = 'person_data.csv'
survey_file = 'survey_data.csv'

# %%
# read all csv files
condition_data = pd.read_csv(os.path.join(dummy_folder, condition_file))
observation_data = pd.read_csv(os.path.join(dummy_folder, observation_file))
person_data = pd.read_csv(os.path.join(dummy_folder, person_file))
survey_data = pd.read_csv(os.path.join(dummy_folder, survey_file))

# %% [markdown]
# ## Observe Datasets
# * Condition: includes diseases
# * Observation: includes location and SDOH
# * Person: includes sex, race, and ethnicity
# * Survey: includes COVID-19 vaccine, healthcare access & utilization, lifestyle, etc.

# %%
condition_data
# Out:
#    person_id  condition_concept_id  \
# 0          1                319835
# 1          2               4157332
# 2          3                439727
# 3          4                321319
# 4          5              36712713
# 5          6               4084229
# 6          7               4065364
# 7          8                440329
# 8          9                137548
#
#                               standard_concept_name  standard_concept_code  \
# 0                          Congestive heart failure           4.234301e+07
# 1               Malignant neoplasm of female breast           3.720640e+08
# 2            Human immunodeficiency virus infection           8.640601e+07
# 3                                    Cardiomyopathy           8.589800e+07
# 4       Primary basal cell carcinoma of left eyelid           1.079110e+15
# 5                                      Primary gout           2.459501e+07
# 6  Follicular cysts of skin and subcutaneous tissue           2.012940e+08
# ...

# %%
observation_data
# Out:
#    person_id  observation_concept_id standard_concept_name  \
# 0          1                 4139934              Homeless
# 1          2                 4139934              Homeless
# 2          3                 4139934              Homeless
# 3          4                 4139934              Homeless
# 4          5                 4139934              Homeless
# 5          6                 4139934              Homeless
# 6          7                 4139934              Homeless
#
#    standard_concept_code standard_vocabulary observation_datetime  \
# 0               32911000              SNOMED       2021/1/29 5:48
# 1               32911000              SNOMED       2020/6/11 6:37
# 2               32911000              SNOMED       2020/6/25 3:02
# 3               32911000              SNOMED      2019/9/16 17:34
# 4               32911000              SNOMED       2019/4/29 0:00
# 5               32911000              SNOMED       2016/4/21 0:00
# ...

# %%
person_data
# Out:
#    person_id  gender_concept_id               gender   date_of_birth  \
# 0          1                  0  No matching concept  1934/6/15 0:00
# 1          2           45880669                 Male  1931/6/15 0:00
# 2          3           45880669                 Male  2002/6/15 0:00
# 3          4           45880669                 Male  2001/6/15 0:00
# 4          5           45878463               Female  2001/6/15 0:00
#
#    race_concept_id            race  ethnicity_concept_id            ethnicity  \
# 0       2100000001  None Indicated                     0  No matching concept
# 1       2100000001  None Indicated              38003563   Hispanic or Latino
# 2       2100000001  None Indicated              38003563   Hispanic or Latino
# 3             8527           White              38003563   Hispanic or Latino
# 4       2100000001  None Indicated              38003563   Hispanic or Latino
#
#    sex_at_birth_concept_id         sex_at_birth
# ...

# %%
survey_data
# Out:
#    person_id   survey_datetime                   survey  question_concept_id  \
# 0          1  2020/11/11 15:41  COVID-19 Vaccine Survey              1310132
# 1          2  2020/11/29 19:54  COVID-19 Vaccine Survey              1310132
# 2          3  2020/11/22 22:37  COVID-19 Vaccine Survey              1310132
# 3          4  2020/11/13 19:02  COVID-19 Vaccine Survey              1310132
# 4          5   2020/11/9 19:35  COVID-19 Vaccine Survey              1310132
# 5          6  2020/11/17 16:22  COVID-19 Vaccine Survey              1310132
# 6          7  2020/11/24 20:46  COVID-19 Vaccine Survey              1310132
# 7          8  2020/11/11 13:54  COVID-19 Vaccine Survey              1310132
# 8          9  2020/11/18 23:02  COVID-19 Vaccine Survey              1310132
#
#                                             question  answer_concept_id  \
# 0  When a COVID-19 vaccine is available to you, h...            1310126
# ...
